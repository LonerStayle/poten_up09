# %% [markdown]
# # 1. 모델 불러오기

# %%
from ultralytics import YOLO
model = YOLO("yolo11n.pt") # 다운로드 위치
# Out:
# YOLO(
#   (model): DetectionModel(
#     (model): Sequential(
#       (0): Conv(
#         (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): Conv(
#         (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): C3k2(
#         (cv1): Conv(
#           (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(48, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(16, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(8, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(8, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (3): Conv(
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (4): C3k2(
#         (cv1): Conv(
#           (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(96, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (5): Conv(
#         (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (6): C3k2(
#         (cv1): Conv(
#           (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): C3k(
#             (cv1): Conv(
#               (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv3): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (m): Sequential(
#               (0): Bottleneck(
#                 (cv1): Conv(
#                   (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#                 (cv2): Conv(
#                   (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#               )
#               (1): Bottleneck(
#                 (cv1): Conv(
#                   (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#                 (cv2): Conv(
#                   (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#               )
#             )
#           )
#         )
#       )
#       (7): Conv(
#         (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (8): C3k2(
#         (cv1): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): C3k(
#             (cv1): Conv(
#               (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv3): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (m): Sequential(
#               (0): Bottleneck(
#                 (cv1): Conv(
#                   (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#                 (cv2): Conv(
#                   (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#               )
#               (1): Bottleneck(
#                 (cv1): Conv(
#                   (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#                 (cv2): Conv(
#                   (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#               )
#             )
#           )
#         )
#       )
#       (9): SPPF(
#         (cv1): Conv(
#           (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#       )
#       (10): C2PSA(
#         (cv1): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): Sequential(
#           (0): PSABlock(
#             (attn): Attention(
#               (qkv): Conv(
#                 (conv): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): Identity()
#               )
#               (proj): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): Identity()
#               )
#               (pe): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): Identity()
#               )
#             )
#             (ffn): Sequential(
#               (0): Conv(
#                 (conv): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (1): Conv(
#                 (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): Identity()
#               )
#             )
#           )
#         )
#       )
#       (11): Upsample(scale_factor=2.0, mode='nearest')
#       (12): Concat()
#       (13): C3k2(
#         (cv1): Conv(
#           (conv): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (14): Upsample(scale_factor=2.0, mode='nearest')
#       (15): Concat()
#       (16): C3k2(
#         (cv1): Conv(
#           (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(96, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (17): Conv(
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (18): Concat()
#       (19): C3k2(
#         (cv1): Conv(
#           (conv): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (20): Conv(
#         (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (21): Concat()
#       (22): C3k2(
#         (cv1): Conv(
#           (conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): C3k(
#             (cv1): Conv(
#               (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv3): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (m): Sequential(
#               (0): Bottleneck(
#                 (cv1): Conv(
#                   (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#                 (cv2): Conv(
#                   (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#               )
#               (1): Bottleneck(
#                 (cv1): Conv(
#                   (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#                 (cv2): Conv(
#                   (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#               )
#             )
#           )
#         )
#       )
#       (23): Detect(
#         (cv2): ModuleList(
#           (0): Sequential(
#             (0): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (1): Sequential(
#             (0): Conv(
#               (conv): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (2): Sequential(
#             (0): Conv(
#               (conv): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (cv3): ModuleList(
#           (0): Sequential(
#             (0): Sequential(
#               (0): DWConv(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#                 (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (1): Conv(
#                 (conv): Conv2d(64, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Sequential(
#               (0): DWConv(
#                 (conv): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=80, bias=False)
#                 (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (1): Conv(
#                 (conv): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (2): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (1): Sequential(
#             (0): Sequential(
#               (0): DWConv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (1): Conv(
#                 (conv): Conv2d(128, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Sequential(
#               (0): DWConv(
#                 (conv): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=80, bias=False)
#                 (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (1): Conv(
#                 (conv): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (2): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (2): Sequential(
#             (0): Sequential(
#               (0): DWConv(
#                 (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#                 (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (1): Conv(
#                 (conv): Conv2d(256, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Sequential(
#               (0): DWConv(
#                 (conv): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=80, bias=False)
#                 (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (1): Conv(
#                 (conv): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (2): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (dfl): DFL(
#           (conv): Conv2d(16, 1, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#       )
#     )
#   )
# )

# %% [markdown]
# # 2. 이미지 예측하기

# %%
# results = moldel(이미지,영상)
# 여러개 예측했을 때 results[이미지1, 이미지2,.....]
# 1개 예측했을 때 results [이미지1]
# 이미지1 = result[0]

# %%
results = model("data/yolo_image.jpg",save = True) # model(), model.predict()
print(type(results)) 
print(len(results))
# Out:
# image 1/1 c:\PythonProject\poten_up09\yolo_image.jpg: 448x640 7 persons, 3 bicycles, 1 umbrella, 55.5ms
# Speed: 1.9ms preprocess, 55.5ms inference, 0.6ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to C:\PythonProject\poten_up09\runs\detect\predict
# <class 'list'>
# 1

# %%
result = results[0] # 이미지 하나에 대한 결과물
result
# Out:
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[209, 191, 168],
#         [209, 191, 168],
#         [210, 192, 169],
#         ...,
#         [214, 197, 178],
#         [215, 198, 179],
#         [216, 199, 180]],
#
#        [[208, 190, 167],
#         [208, 190, 167],
#         [209, 191, 168],
#         ...,
#         [213, 196, 177],
#         [213, 196, 177],
#         [213, 196, 177]],
#
#        [[208, 190, 167],
#         [208, 190, 167],
#         [209, 191, 168],
#         ...,
#         [214, 197, 178],
#         [214, 197, 178],
#         [214, 197, 178]],
#
#        ...,
#
#        [[126, 145, 158],
#         [118, 137, 150],
#         [121, 140, 153],
#         ...,
#         [130, 159, 164],
#         [116, 147, 150],
#         [124, 155, 156]],
#
#        [[117, 137, 148],
#         [102, 122, 133],
#         [116, 136, 147],
#         ...,
#         [134, 160, 167],
#         [122, 151, 156],
#         [130, 159, 163]],
#
#        [[119, 140, 148],
#         [105, 126, 134],
#         [ 98, 119, 127],
#         ...,
#         [128, 154, 161],
#         [128, 154, 161],
#         [140, 166, 172]]], shape=(854, 1280, 3), dtype=uint8)
# orig_shape: (854, 1280)
# path: 'c:\\PythonProject\\poten_up09\\yolo_image.jpg'
# probs: None
# save_dir: 'C:\\PythonProject\\poten_up09\\runs\\detect\\predict'
# speed: {'preprocess': 1.8584000008559087, 'inference': 55.54809999921417, 'postprocess': 0.6386000004567904}

# %%
# result 에는 이미지에 대한 예측 결과 또는 정보가 담겨있는데
print(result.names) # yolo11n 모델이 찾을 수 있는 객체 딕셔너리
print(result.boxes) # 이미지에서 찾은 객체 정보들이 들어있다.
# Out:
# {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([ 1.,  0.,  1.,  1.,  0.,  0.,  0.,  0.,  0., 25.,  0.])
# conf: tensor([0.9002, 0.8530, 0.8465, 0.8233, 0.6742, 0.6726, 0.5206, 0.4078, 0.3751, 0.3393, 0.2988])
# data: tensor([[6.2712e+02, 3.9485e+02, 1.0357e+03, 7.7144e+02, 9.0023e-01, 1.0000e+00],
#         [3.8486e+02, 2.1434e+02, 5.8382e+02, 7.4489e+02, 8.5297e-01, 0.0000e+00],
#         [3.1211e+02, 4.2675e+02, 6.2185e+02, 7.6588e+02, 8.4648e-01, 1.0000e+00],
#         [2.0947e+01, 3.8343e+02, 2.8015e+02, 6.5619e+02, 8.2332e-01, 1.0000e+00],
#         [8.3186e+02, 1.8188e+02, 1.0133e+03, 7.0348e+02, 6.7417e-01, 0.0000e+00],
#         [1.1804e+02, 2.4416e+02, 2.8153e+02, 6.3568e+02, 6.7262e-01, 0.0000e+00],
#         [0.0926, 0.2853, 0.2198, 0.6062]])

# %%
# 예측 결과 확인하기 
boxes = result.boxes
boxes # cls, conf, data
# cls 예측 클래스
# conf 예측 신뢰도
# data 박스좌표, 신뢰도, 클래스
# 길이 ====> 찾은 객체의 수

# %%
print(boxes.cls)
print(boxes.conf)
print(boxes.data)

# %% [markdown]
# # 3. 영상 예측하기

# %%
# # Load a model
# model = YOLO("yolo11n.pt")  # load an official model
# model = YOLO("path/to/best.pt")  # load a custom model

# # Predict with the model
# results = model("https://ultralytics.com/images/bus.jpg")  # predict on an image

# # Access the results
# for result in results:
#     xywh = result.boxes.xywh  # center-x, center-y, width, height
#     xywhn = result.boxes.xywhn  # normalized
#     xyxy = result.boxes.xyxy  # top-left-x, top-left-y, bottom-right-x, bottom-right-y
#     xyxyn = result.boxes.xyxyn  # normalized
#     names = [result.names[cls.item()] for cls in result.boxes.cls.int()]  # class name of each box
#     confs = result.boxes.conf  # confidence score of each box

youtube_url = "https://youtu.be/S5nsDT5oU90"

# %%
results = model(youtube_url, stream=True, show=True)
for res in results:
    print(res)
# Out:
# requirements: Ultralytics requirement ['pytubefix>=6.5.2'] not found, attempting AutoUpdate...
#
# requirements: AutoUpdate success  0.6s
# WARNING requirements: Restart runtime or rerun command for updates to take effect
#
# 1/1: https://youtu.be/S5nsDT5oU90... Success  (3481 frames of shape 3840x2160 at 23.98 FPS)
#
# 0: 384x640 1 person, 114.0ms
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 61,  61,  73],
#         [ 61,  61,  73],
#         [ 61,  61,  73],
#         ...,
#         [ 67,  72,  85],
#         [ 67,  72,  85],
#         [ 67,  72,  85]],
#
#        [[ 61,  61,  73],
#         [ 61,  61,  73],
#         [ 61,  61,  73],
#         ...,
#         [ 67,  72,  85],
#         [ 67,  72,  85],
#         [ 67,  72,  85]],
#
#        [[ 61,  61,  73],
#         [ 61,  61,  73],
#         [ 61,  61,  73],
#         ...,
#         [ 67,  72,  85],
#         [ 67,  72,  85],
#         [ 67,  72,  85]],
#
#        ...,
#
#        [[150, 140, 147],
#         [150, 140, 147],
#         [150, 140, 147],
#         ...,
#         [166, 156, 163],
#         [166, 156, 163],
#         [166, 156, 163]],
#
#        [[150, 140, 147],
#         [150, 140, 147],
#         [150, 140, 147],
#         ...,
#         [166, 156, 163],
#         [166, 156, 163],
#         [166, 156, 163]],
#
#        [[150, 140, 147],
#         [150, 140, 147],
#         [150, 140, 147],
#         ...,
#         [166, 156, 163],
#         [166, 156, 163],
#         [166, 156, 163]]], shape=(2160, 3840, 3), dtype=uint8)
# orig_shape: (2160, 3840)
# path: 'https_//youtu.be/S5nsDT5oU90'
# probs: None
# save_dir: 'C:\\PythonProject\\poten_up09\\runs\\detect\\predict'
# speed: {'preprocess': 2.7859999991051154, 'inference': 113.99810000148136, 'postprocess': 1.2797999988833908}
# 0: 384x640 1 person, 84.1ms
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 61,  61,  73],
#         [ 61,  61,  73],
#         [ 61,  61,  73],
#         ...,
#         [ 69,  74,  87],
#         [ 69,  74,  87],
#         [ 69,  74,  87]],
#
#        [[ 61,  61,  73],
#         [ 61,  61,  73],
#         [ 61,  61,  73],
#         ...,
#         [ 69,  74,  87],
#         [ 69,  74,  87],
#         [ 69,  74,  87]],
#
#        [[ 60,  61,  71],
#         [ 61,  62,  72],
#         [ 61,  62,  72],
#         ...,
#         [ 69,  74,  87],
#         [ 69,  74,  87],
#         [ 69,  74,  87]],
#
#        ...,
#
#        [[150, 140, 147],
#         [149, 139, 146],
#         [149, 139, 146],
#         ...,
#         [166, 156, 163],
#         [166, 156, 163],
#         [166, 156, 163]],
#
#        [[149, 139, 146],
#         [149, 139, 146],
#         [149, 139, 146],
#         ...,
#         [166, 156, 163],
#         [166, 156, 163],
#         [166, 156, 163]],
#
#        [[149, 139, 146],
#         [149, 139, 146],
#         [149, 139, 146],
#         ...,
#         [166, 156, 163],
#         [166, 156, 163],
#         [166, 156, 163]]], shape=(2160, 3840, 3), dtype=uint8)
# orig_shape: (2160, 3840)
# path: 'https_//youtu.be/S5nsDT5oU90'
# probs: None
# save_dir: 'C:\\PythonProject\\poten_up09\\runs\\detect\\predict'
# speed: {'preprocess': 2.7484999991429504, 'inference': 84.10860000003595, 'postprocess': 0.7533999996667262}
# 0: 384x640 1 person, 88.5ms
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 60,  61,  71],
#         [ 61,  62,  72],
#         [ 61,  62,  72],
#         ...,
#         [ 70,  75,  86],
#         [ 70,  75,  86],
#         [ 70,  75,  86]],
#
#        [[ 60,  61,  71],
#         [ 60,  61,  71],
#         [ 61,  62,  72],
#         ...,
#         [ 71,  76,  87],
#         [ 71,  76,  87],
#         [ 70,  75,  86]],
#
#        [[ 60,  61,  71],
#         [ 60,  61,  71],
#         [ 60,  61,  71],
#         ...,
#         [ 71,  76,  87],
#         [ 71,  76,  87],
#         [ 71,  76,  87]],
#
#        ...,
#
#        [[150, 140, 147],
#         [150, 140, 147],
#         [150, 140, 147],
#         ...,
#         [167, 157, 164],
#         [167, 157, 164],
#         [167, 157, 164]],
#
#        [[150, 140, 147],
#         [150, 140, 147],
#         [150, 140, 147],
#         ...,
#         [167, 157, 164],
#         [167, 157, 164],
#         [167, 157, 164]],
#
#        [[149, 139, 146],
#         [149, 139, 146],
#         [149, 139, 146],
#         ...,
#         [167, 157, 164],
#         [167, 157, 164],
#         [167, 157, 164]]], shape=(2160, 3840, 3), dtype=uint8)
# orig_shape: (2160, 3840)
# path: 'https_//youtu.be/S5nsDT5oU90'
# probs: None
# save_dir: 'C:\\PythonProject\\poten_up09\\runs\\detect\\predict'
# speed: {'preprocess': 3.4172999985457864, 'inference': 88.54400000018359, 'postprocess': 1.2092999986634823}
# 0: 384x640 1 person, 62.4ms
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 60,  61,  71],
#         [ 60,  61,  71],
#         [ 60,  61,  71],
#         ...,
#         [ 76,  80,  89],
#         [ 76,  80,  89],
#         [ 78,  82,  91]],
#
#        [[ 60,  61,  71],
#         [ 60,  61,  71],
#         [ 60,  61,  71],
#         ...,
#         [ 79,  83,  92],
#         [ 79,  83,  92],
#         [ 78,  82,  91]],
#
#        [[ 60,  61,  71],
#         [ 60,  61,  71],
#         [ 60,  61,  71],
#         ...,
#         [ 81,  82,  92],
#         [ 81,  82,  92],
#         [ 80,  81,  91]],
#
#        ...,
#
#        [[150, 140, 147],
#         [149, 139, 146],
#         [149, 139, 146],
#         ...,
#         [167, 157, 164],
#         [167, 157, 164],
#         [167, 157, 164]],
#
#        [[150, 140, 147],
#         [149, 139, 146],
#         [149, 139, 146],
#         ...,
#         [167, 157, 164],
#         [167, 157, 164],
#         [167, 157, 164]],
#
#        [[149, 139, 146],
#         [149, 139, 146],
#         [148, 138, 145],
#         ...,
#         [167, 157, 164],
#         [167, 157, 164],
#         [167, 157, 164]]], shape=(2160, 3840, 3), dtype=uint8)
# orig_shape: (2160, 3840)
# path: 'https_//youtu.be/S5nsDT5oU90'
# probs: None
# save_dir: 'C:\\PythonProject\\poten_up09\\runs\\detect\\predict'
# speed: {'preprocess': 1.8826000014087185, 'inference': 62.404600001173094, 'postprocess': 1.115600000048289}
# 0: 384x640 1 person, 84.4ms
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 61,  61,  68],
#         [ 61,  61,  68],
#         [ 61,  61,  68],
#         ...,
#         [ 93,  91,  96],
#         [ 90,  91,  96],
#         [ 90,  91,  96]],
#
#        [[ 61,  61,  68],
#         [ 61,  61,  68],
#         [ 61,  61,  68],
#         ...,
#         [ 94,  92,  97],
#         [ 90,  91,  96],
#         [ 90,  91,  96]],
#
#        [[ 61,  61,  68],
#         [ 61,  61,  68],
#         [ 61,  61,  68],
#         ...,
#         [ 94,  92,  97],
#         [ 94,  92,  97],
#         [ 94,  92,  97]],
#
#        ...,
#
#        [[148, 138, 145],
#         [148, 138, 145],
#         [148, 138, 145],
#         ...,
#         [167, 157, 164],
#         [167, 157, 164],
#         [167, 157, 164]],
#
#        [[148, 138, 145],
#         [148, 138, 145],
#         [148, 138, 145],
#         ...,
#         [167, 157, 164],
#         [167, 157, 164],
#         [167, 157, 164]],
#
#        [[148, 138, 145],
#         [148, 138, 145],
#         [148, 138, 145],
#         ...,
#         [167, 157, 164],
#         [167, 157, 164],
#         [167, 157, 164]]], shape=(2160, 3840, 3), dtype=uint8)
# orig_shape: (2160, 3840)
# path: 'https_//youtu.be/S5nsDT5oU90'
# probs: None
# save_dir: 'C:\\PythonProject\\poten_up09\\runs\\detect\\predict'
# speed: {'preprocess': 3.4814999999071006, 'inference': 84.42730000024312, 'postprocess': 0.7464999998774147}
# 0: 384x640 1 person, 79.5ms
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 65,  62,  69],
#         [ 65,  62,  69],
#         [ 65,  62,  69],
#         ...,
#         [111, 105, 108],
#         [111, 105, 108],
#         [111, 105, 108]],
#
#        [[ 66,  63,  70],
#         [ 66,  63,  70],
#         [ 66,  63,  70],
#         ...,
#         [112, 106, 109],
#         [111, 105, 108],
#         [111, 105, 108]],
#
#        [[ 66,  64,  69],
#         [ 66,  64,  69],
#         [ 66,  64,  69],
#         ...,
#         [114, 105, 109],
#         [114, 105, 109],
#         [114, 105, 109]],
#
#        ...,
#
#        [[149, 139, 146],
#         [149, 139, 146],
#         [149, 139, 146],
#         ...,
#         [166, 156, 163],
#         [166, 156, 163],
#         [166, 156, 163]],
#
#        [[149, 139, 146],
#         [149, 139, 146],
#         [149, 139, 146],
#         ...,
#         [166, 156, 163],
#         [166, 156, 163],
#         [166, 156, 163]],
#
#        [[149, 139, 146],
#         [149, 139, 146],
#         [149, 139, 146],
#         ...,
#         [165, 155, 162],
#         [166, 156, 163],
#         [166, 156, 163]]], shape=(2160, 3840, 3), dtype=uint8)
# orig_shape: (2160, 3840)
# path: 'https_//youtu.be/S5nsDT5oU90'
# probs: None
# save_dir: 'C:\\PythonProject\\poten_up09\\runs\\detect\\predict'
# speed: {'preprocess': 3.695800000059535, 'inference': 79.54889999928128, 'postprocess': 0.6744999991497025}
# 0: 384x640 1 person, 100.2ms
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 77,  72,  78],
#         [ 77,  72,  78],
#         [ 77,  72,  78],
#         ...,
#         [113, 104, 108],
#         [113, 104, 108],
#         [113, 104, 108]],
#
#        [[ 78,  73,  79],
#         [ 78,  73,  79],
#         [ 78,  73,  79],
#         ...,
#         [113, 104, 108],
#         [113, 104, 108],
#         [113, 104, 108]],
#
#        [[ 80,  75,  81],
#         [ 80,  75,  81],
#         [ 80,  75,  81],
#         ...,
#         [113, 104, 108],
#         [113, 104, 108],
#         [113, 104, 108]],
#
#        ...,
#
#        [[153, 141, 148],
#         [153, 141, 148],
#         [153, 141, 148],
#         ...,
#         [164, 154, 161],
#         [164, 154, 161],
#         [164, 154, 161]],
#
#        [[153, 141, 148],
#         [153, 141, 148],
#         [153, 141, 148],
#         ...,
#         [164, 154, 161],
#         [164, 154, 161],
#         [164, 154, 161]],
#
#        [[153, 141, 148],
#         [153, 141, 148],
#         [153, 141, 148],
#         ...,
#         [164, 154, 161],
#         [164, 154, 161],
#         [164, 154, 161]]], shape=(2160, 3840, 3), dtype=uint8)
# orig_shape: (2160, 3840)
# path: 'https_//youtu.be/S5nsDT5oU90'
# probs: None
# save_dir: 'C:\\PythonProject\\poten_up09\\runs\\detect\\predict'
# speed: {'preprocess': 2.338700000109384, 'inference': 100.24259999954666, 'postprocess': 0.6549000008817529}
# 0: 384x640 1 person, 79.0ms
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 91,  84,  90],
#         [ 92,  85,  91],
#         [ 92,  85,  91],
#         ...,
#         [109, 100, 104],
#         [109, 100, 104],
#         [109, 100, 104]],
#
#        [[ 92,  85,  91],
#         [ 92,  85,  91],
#         [ 92,  85,  91],
#         ...,
#         [108,  99, 103],
#         [108,  99, 103],
#         [108,  99, 103]],
#
#        [[ 93,  86,  92],
#         [ 93,  86,  92],
#         [ 93,  86,  92],
#         ...,
#         [108,  99, 103],
#         [108,  99, 103],
#         [108,  99, 103]],
#
#        ...,
#
#        [[158, 146, 153],
#         [158, 146, 153],
#         [158, 146, 153],
#         ...,
#         [164, 154, 161],
#         [164, 154, 161],
#         [164, 154, 161]],
#
#        [[158, 146, 153],
#         [158, 146, 153],
#         [158, 146, 153],
#         ...,
#         [164, 154, 161],
#         [164, 154, 161],
#         [164, 154, 161]],
#
#        [[158, 146, 153],
#         [158, 146, 153],
#         [158, 146, 153],
#         ...,
#         [164, 154, 161],
#         [164, 154, 161],
#         [164, 154, 161]]], shape=(2160, 3840, 3), dtype=uint8)
# orig_shape: (2160, 3840)
# path: 'https_//youtu.be/S5nsDT5oU90'
# probs: None
# save_dir: 'C:\\PythonProject\\poten_up09\\runs\\detect\\predict'
# speed: {'preprocess': 2.951599999505561, 'inference': 79.03430000078515, 'postprocess': 1.1651999993773643}
# 0: 384x640 1 person, 1 toilet, 92.2ms
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[113, 103, 105],
#         [113, 103, 105],
#         [113, 103, 105],
#         ...,
#         [ 92,  86,  94],
#         [ 92,  86,  94],
#         [ 92,  86,  94]],
#
#        [[115, 105, 107],
#         [115, 105, 107],
#         [115, 105, 107],
#         ...,
#         [ 91,  85,  93],
#         [ 91,  85,  93],
#         [ 91,  85,  93]],
#
#        [[115, 105, 107],
#         [115, 105, 107],
#         [115, 105, 107],
#         ...,
#         [ 90,  84,  92],
#         [ 90,  84,  92],
#         [ 90,  84,  92]],
#
#        ...,
#
#        [[157, 145, 152],
#         [157, 145, 152],
#         [157, 145, 152],
#         ...,
#         [167, 157, 164],
#         [167, 157, 164],
#         [167, 157, 164]],
#
#        [[157, 145, 152],
#         [157, 145, 152],
#         [157, 145, 152],
#         ...,
#         [166, 156, 163],
#         [167, 157, 164],
#         [167, 157, 164]],
#
#        [[157, 145, 152],
#         [158, 146, 153],
#         [158, 146, 153],
#         ...,
#         [166, 156, 163],
#         [166, 156, 163],
#         [166, 156, 163]]], shape=(2160, 3840, 3), dtype=uint8)
# orig_shape: (2160, 3840)
# path: 'https_//youtu.be/S5nsDT5oU90'
# probs: None
# save_dir: 'C:\\PythonProject\\poten_up09\\runs\\detect\\predict'
# speed: {'preprocess': 2.602900000056252, 'inference': 92.22390000104497, 'postprocess': 0.6524000000354135}
# 0: 384x640 1 person, 1 backpack, 80.1ms
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[102,  94,  96],
#         [102,  94,  96],
#         [102,  94,  96],
#         ...,
#         [ 56,  56,  63],
#         [ 56,  56,  63],
#         [ 56,  56,  63]],
#
#        [[101,  93,  95],
#         [101,  93,  95],
#         [101,  93,  95],
#         ...,
#         [ 54,  54,  61],
#         [ 54,  54,  61],
#         [ 54,  54,  61]],
#
#        [[101,  93,  95],
#         [101,  93,  95],
#         [101,  93,  95],
#         ...,
#         [ 52,  52,  59],
#         [ 52,  52,  59],
#         [ 52,  52,  59]],
#
#        ...,
#
#        [[144, 134, 141],
#         [144, 134, 141],
#         [144, 134, 141],
#         ...,
#         [179, 169, 176],
#         [179, 169, 176],
#         [179, 169, 176]],
#
#        [[143, 133, 140],
#         [143, 133, 140],
#         [143, 133, 140],
#         ...,
#         [179, 169, 176],
#         [179, 169, 176],
#         [179, 169, 176]],
#
#        [[144, 134, 141],
#         [144, 134, 141],
#         [143, 133, 140],
#         ...,
#         [179, 169, 176],
#         [179, 169, 176],
#         [179, 169, 176]]], shape=(2160, 3840, 3), dtype=uint8)
# orig_shape: (2160, 3840)
# path: 'https_//youtu.be/S5nsDT5oU90'
# probs: None
# save_dir: 'C:\\PythonProject\\poten_up09\\runs\\detect\\predict'
# speed: {'preprocess': 4.037299999254174, 'inference': 80.13910000045144, 'postprocess': 0.886499999978696}
# 0: 384x640 1 person, 92.5ms
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 85,  80,  86],
#         [ 85,  80,  86],
#         [ 85,  80,  86],
#         ...,
#         [ 60,  58,  63],
#         [ 59,  57,  62],
#         [ 59,  57,  62]],
#
#        [[ 84,  79,  85],
#         [ 84,  79,  85],
#         [ 84,  79,  85],
#         ...,
#         [ 60,  58,  63],
#         [ 60,  58,  63],
#         [ 60,  58,  63]],
#
#        [[ 83,  78,  84],
#         [ 82,  77,  83],
#         [ 83,  78,  84],
#         ...,
#         [ 61,  59,  64],
#         [ 61,  59,  64],
#         [ 61,  59,  64]],
#
#        ...,
#
#        [[152, 141, 150],
#         [152, 141, 150],
#         [150, 139, 148],
#         ...,
#         [179, 169, 176],
#         [179, 169, 176],
#         [179, 169, 176]],
#
#        [[153, 142, 151],
#         [151, 140, 149],
#         [149, 138, 147],
#         ...,
#         [179, 169, 176],
#         [179, 169, 176],
#         [179, 169, 176]],
#
#        [[153, 142, 151],
#         [151, 140, 149],
#         [149, 138, 147],
#         ...,
#         [179, 169, 176],
#         [179, 169, 176],
#         [179, 169, 176]]], shape=(2160, 3840, 3), dtype=uint8)
# orig_shape: (2160, 3840)
# path: 'https_//youtu.be/S5nsDT5oU90'
# probs: None
# save_dir: 'C:\\PythonProject\\poten_up09\\runs\\detect\\predict'
# speed: {'preprocess': 2.8200999986438546, 'inference': 92.48609999849577, 'postprocess': 1.371399999698042}
# 0: 384x640 2 persons, 56.6ms
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 52,  50,  55],
#         [ 52,  50,  55],
#         [ 52,  50,  55],
#         ...,
#         [ 91,  85,  88],
#         [ 91,  85,  88],
#         [ 91,  85,  88]],
#
#        [[ 52,  50,  55],
#         [ 52,  50,  55],
#         [ 52,  50,  55],
#         ...,
#         [ 91,  85,  88],
#         [ 92,  86,  89],
#         [ 92,  86,  89]],
#
#        [[ 52,  50,  55],
#         [ 52,  50,  55],
#         [ 52,  50,  55],
#         ...,
#         [ 93,  87,  90],
#         [ 93,  87,  90],
#         [ 93,  87,  90]],
#
#        ...,
#
#        [[172, 162, 169],
#         [172, 162, 169],
#         [172, 162, 169],
#         ...,
#         [167, 157, 164],
#         [169, 159, 166],
#         [169, 159, 166]],
#
#        [[172, 162, 169],
#         [172, 162, 169],
#         [172, 162, 169],
#         ...,
#         [167, 157, 164],
#         [167, 157, 164],
#         [167, 157, 164]],
#
#        [[172, 162, 169],
#         [172, 162, 169],
#         [172, 162, 169],
#         ...,
#         [167, 157, 164],
#         [167, 157, 164],
#         [167, 157, 164]]], shape=(2160, 3840, 3), dtype=uint8)
# orig_shape: (2160, 3840)
# path: 'https_//youtu.be/S5nsDT5oU90'
# probs: None
# save_dir: 'C:\\PythonProject\\poten_up09\\runs\\detect\\predict'
# speed: {'preprocess': 2.742899998338544, 'inference': 56.580599999506376, 'postprocess': 1.2534999987110496}
# 0: 384x640 3 persons, 63.7ms
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 60,  54,  62],
#         [ 60,  54,  62],
#         [ 60,  54,  62],
#         ...,
#         [102,  96,  99],
#         [102,  96,  99],
#         [102,  96,  99]],
#
#        [[ 61,  55,  63],
#         [ 61,  55,  63],
#         [ 61,  55,  63],
#         ...,
#         [102,  96,  99],
#         [102,  96,  99],
#         [102,  96,  99]],
#
#        [[ 62,  56,  64],
#         [ 62,  56,  64],
#         [ 62,  56,  64],
#         ...,
#         [101,  95,  98],
#         [101,  95,  98],
#         [101,  95,  98]],
#
#        ...,
#
#        [[172, 162, 169],
#         [173, 163, 170],
#         [173, 163, 170],
#         ...,
#         [169, 159, 166],
#         [167, 157, 164],
#         [167, 157, 164]],
#
#        [[172, 162, 169],
#         [173, 163, 170],
#         [173, 163, 170],
#         ...,
#         [170, 160, 167],
#         [169, 159, 166],
#         [169, 159, 166]],
#
#        [[173, 163, 170],
#         [173, 163, 170],
#         [173, 163, 170],
#         ...,
#         [171, 161, 168],
#         [170, 160, 167],
#         [170, 160, 167]]], shape=(2160, 3840, 3), dtype=uint8)
# orig_shape: (2160, 3840)
# path: 'https_//youtu.be/S5nsDT5oU90'
# probs: None
# save_dir: 'C:\\PythonProject\\poten_up09\\runs\\detect\\predict'
# speed: {'preprocess': 1.6634000003250549, 'inference': 63.744500001121196, 'postprocess': 1.6322999999829335}
# 0: 384x640 3 persons, 70.2ms
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 82,  76,  79],
#         [ 82,  76,  79],
#         [ 82,  76,  79],
#         ...,
#         [ 92,  87,  93],
#         [ 92,  87,  93],
#         [ 92,  87,  93]],
#
#        [[ 83,  77,  80],
#         [ 83,  77,  80],
#         [ 83,  77,  80],
#         ...,
#         [ 91,  86,  92],
#         [ 91,  86,  92],
#         [ 91,  86,  92]],
#
#        [[ 83,  77,  80],
#         [ 83,  77,  80],
#         [ 83,  77,  80],
#         ...,
#         [ 90,  85,  91],
#         [ 91,  86,  92],
#         [ 91,  86,  92]],
#
#        ...,
#
#        [[167, 157, 164],
#         [166, 156, 163],
#         [166, 156, 163],
#         ...,
#         [166, 156, 163],
#         [166, 156, 163],
#         [167, 157, 164]],
#
#        [[166, 156, 163],
#         [165, 155, 162],
#         [165, 155, 162],
#         ...,
#         [166, 156, 163],
#         [166, 156, 163],
#         [166, 156, 163]],
#
#        [[166, 156, 163],
#         [165, 155, 162],
#         [165, 155, 162],
#         ...,
#         [167, 157, 164],
#         [167, 157, 164],
#         [167, 157, 164]]], shape=(2160, 3840, 3), dtype=uint8)
# orig_shape: (2160, 3840)
# path: 'https_//youtu.be/S5nsDT5oU90'
# probs: None
# save_dir: 'C:\\PythonProject\\poten_up09\\runs\\detect\\predict'
# speed: {'preprocess': 1.8251999990752665, 'inference': 70.17450000057579, 'postprocess': 0.6558999994012993}
# 0: 384x640 4 persons, 85.4ms
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 52,  50,  55],
#         [ 52,  50,  55],
#         [ 50,  48,  53],
#         ...,
#         [ 68,  75,  88],
#         [ 68,  75,  88],
#         [ 68,  75,  88]],
#
#        [[ 51,  49,  54],
#         [ 51,  49,  54],
#         [ 51,  49,  54],
#         ...,
#         [ 68,  75,  88],
#         [ 68,  75,  88],
#         [ 68,  75,  88]],
#
#        [[ 51,  49,  54],
#         [ 51,  49,  54],
#         [ 51,  49,  54],
#         ...,
#         [ 68,  75,  88],
#         [ 68,  75,  88],
#         [ 68,  75,  88]],
#
#        ...,
#
#        [[170, 160, 167],
#         [171, 161, 168],
#         [171, 161, 168],
#         ...,
#         [178, 168, 175],
#         [178, 168, 175],
#         [178, 168, 175]],
#
#        [[169, 159, 166],
#         [169, 159, 166],
#         [171, 161, 168],
#         ...,
#         [179, 169, 176],
#         [179, 169, 176],
#         [179, 169, 176]],
#
#        [[169, 159, 166],
#         [169, 159, 166],
#         [170, 160, 167],
#         ...,
#         [179, 169, 176],
#         [179, 169, 176],
#         [179, 169, 176]]], shape=(2160, 3840, 3), dtype=uint8)
# orig_shape: (2160, 3840)
# path: 'https_//youtu.be/S5nsDT5oU90'
# probs: None
# save_dir: 'C:\\PythonProject\\poten_up09\\runs\\detect\\predict'
# speed: {'preprocess': 1.902199999676668, 'inference': 85.39999999993597, 'postprocess': 1.2565999986691168}
# 0: 384x640 6 persons, 66.1ms
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 51,  49,  54],
#         [ 51,  49,  54],
#         [ 51,  49,  54],
#         ...,
#         [ 68,  75,  86],
#         [ 68,  75,  86],
#         [ 68,  75,  86]],
#
#        [[ 51,  49,  54],
#         [ 51,  49,  54],
#         [ 51,  49,  54],
#         ...,
#         [ 68,  75,  86],
#         [ 68,  75,  86],
#         [ 68,  75,  86]],
#
#        [[ 51,  49,  54],
#         [ 51,  49,  54],
#         [ 51,  49,  54],
#         ...,
#         [ 68,  75,  86],
#         [ 68,  75,  86],
#         [ 68,  75,  86]],
#
#        ...,
#
#        [[174, 162, 169],
#         [174, 162, 169],
#         [174, 162, 169],
#         ...,
#         [176, 166, 173],
#         [174, 164, 171],
#         [174, 164, 171]],
#
#        [[176, 164, 171],
#         [176, 164, 171],
#         [175, 163, 170],
#         ...,
#         [178, 168, 175],
#         [178, 168, 175],
#         [177, 167, 174]],
#
#        [[178, 166, 173],
#         [178, 166, 173],
#         [176, 164, 171],
#         ...,
#         [179, 169, 176],
#         [179, 169, 176],
#         [179, 169, 176]]], shape=(2160, 3840, 3), dtype=uint8)
# orig_shape: (2160, 3840)
# path: 'https_//youtu.be/S5nsDT5oU90'
# probs: None
# save_dir: 'C:\\PythonProject\\poten_up09\\runs\\detect\\predict'
# speed: {'preprocess': 3.100800000538584, 'inference': 66.11139999949955, 'postprocess': 1.0285999996995088}
# 0: 384x640 4 persons, 63.0ms
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 54,  49,  55],
#         [ 53,  48,  54],
#         [ 51,  49,  54],
#         ...,
#         [ 77,  77,  84],
#         [ 75,  75,  82],
#         [ 70,  70,  77]],
#
#        [[ 53,  48,  54],
#         [ 53,  48,  54],
#         [ 51,  49,  54],
#         ...,
#         [ 77,  77,  84],
#         [ 73,  73,  80],
#         [ 69,  69,  76]],
#
#        [[ 53,  48,  54],
#         [ 53,  48,  54],
#         [ 51,  49,  54],
#         ...,
#         [ 76,  77,  82],
#         [ 72,  73,  78],
#         [ 68,  69,  74]],
#
#        ...,
#
#        [[156, 146, 153],
#         [158, 148, 155],
#         [160, 150, 157],
#         ...,
#         [176, 166, 173],
#         [176, 166, 173],
#         [177, 167, 174]],
#
#        [[159, 149, 156],
#         [162, 152, 159],
#         [164, 154, 161],
#         ...,
#         [176, 166, 173],
#         [176, 166, 173],
#         [177, 167, 174]],
#
#        [[163, 153, 160],
#         [165, 155, 162],
#         [166, 156, 163],
#         ...,
#         [176, 166, 173],
#         [176, 166, 173],
#         [176, 166, 173]]], shape=(2160, 3840, 3), dtype=uint8)
# orig_shape: (2160, 3840)
# path: 'https_//youtu.be/S5nsDT5oU90'
# probs: None
# save_dir: 'C:\\PythonProject\\poten_up09\\runs\\detect\\predict'
# speed: {'preprocess': 2.0692999987659277, 'inference': 63.040500001079636, 'postprocess': 0.6680000005871989}
# 0: 384x640 6 persons, 65.5ms
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 52,  50,  55],
#         [ 52,  50,  55],
#         [ 52,  50,  55],
#         ...,
#         [ 63,  65,  72],
#         [ 63,  65,  72],
#         [ 63,  65,  72]],
#
#        [[ 52,  50,  55],
#         [ 52,  50,  55],
#         [ 52,  50,  55],
#         ...,
#         [ 63,  65,  72],
#         [ 63,  65,  72],
#         [ 63,  65,  72]],
#
#        [[ 53,  51,  56],
#         [ 53,  51,  56],
#         [ 53,  51,  56],
#         ...,
#         [ 63,  65,  72],
#         [ 63,  65,  72],
#         [ 63,  65,  72]],
#
#        ...,
#
#        [[168, 157, 161],
#         [167, 156, 160],
#         [167, 156, 160],
#         ...,
#         [167, 157, 164],
#         [167, 157, 164],
#         [167, 157, 164]],
#
#        [[167, 156, 160],
#         [167, 156, 160],
#         [167, 156, 160],
#         ...,
#         [170, 160, 167],
#         [170, 160, 167],
#         [170, 160, 167]],
#
#        [[166, 155, 159],
#         [166, 155, 159],
#         [166, 155, 159],
#         ...,
#         [171, 161, 168],
#         [172, 162, 169],
#         [172, 162, 169]]], shape=(2160, 3840, 3), dtype=uint8)
# orig_shape: (2160, 3840)
# path: 'https_//youtu.be/S5nsDT5oU90'
# probs: None
# save_dir: 'C:\\PythonProject\\poten_up09\\runs\\detect\\predict'
# ...
# obb: None
# orig_img: array([[[ 82,  74,  76],
#         [ 82,  74,  76],
#         [ 82,  74,  76],
#         ...,
#         [ 43,  47,  56],
#         [ 43,  47,  56],
#         [ 43,  47,  56]],
#
#        [[ 82,  74,  76],
#         [ 82,  74,  76],
#         [ 82,  74,  76],
#         ...,
#         [ 43,  47,  56],
#         [ 43,  47,  56],
#         [ 43,  47,  56]],
#
#        [[ 81,  73,  75],
#         [ 81,  73,  75],
#         [ 81,  73,  75],
#         ...,
#         [ 43,  47,  56],
#         [ 43,  47,  56],
#         [ 43,  47,  56]],
#
#        ...,
#
#        [[ 96,  86,  93],
#         [ 96,  86,  93],
#         [ 96,  86,  93],
#         ...,
#         [130, 119, 123],
#         [126, 115, 119],
#         [124, 113, 117]],
#
#        [[ 96,  86,  93],
#         [ 96,  86,  93],
#         [ 96,  86,  93],
#         ...,
#         [140, 129, 133],
#         [137, 126, 130],
#         [136, 125, 129]],
#
#        [[ 96,  86,  93],
#         [ 97,  87,  94],
#         [ 99,  89,  96],
#         ...,
#         [144, 133, 137],
#         [143, 132, 136],
#         [144, 133, 137]]], shape=(2160, 3840, 3), dtype=uint8)
# orig_shape: (2160, 3840)
# path: 'https_//youtu.be/S5nsDT5oU90'
# probs: None
# save_dir: 'C:\\PythonProject\\poten_up09\\runs\\detect\\predict'
# speed: {'preprocess': 3.6782999995921273, 'inference': 92.62429999944288, 'postprocess': 1.3638999989780132}
# 0: 384x640 8 persons, 76.4ms
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 51,  56,  67],
#         [ 51,  56,  67],
#         [ 51,  56,  67],
#         ...,
#         [ 75,  70,  71],
#         [ 75,  70,  71],
#         [ 75,  70,  71]],
#
#        [[ 51,  56,  67],
#         [ 51,  56,  67],
#         [ 51,  56,  67],
#         ...,
#         [ 75,  70,  71],
#         [ 75,  70,  71],
#         [ 75,  70,  71]],
#
#        [[ 51,  56,  67],
#         [ 51,  56,  67],
#         [ 51,  56,  67],
#         ...,
#         [ 75,  70,  71],
#         [ 75,  70,  71],
#         [ 75,  70,  71]],
#
#        ...,
#
#        [[101,  90,  94],
#         [101,  90,  94],
#         [101,  90,  94],
#         ...,
#         [146, 135, 139],
#         [146, 135, 139],
#         [146, 135, 139]],
#
#        [[101,  90,  94],
#         [101,  90,  94],
#         [101,  90,  94],
#         ...,
#         [146, 135, 139],
#         [146, 135, 139],
#         [146, 135, 139]],
#
#        [[101,  90,  94],
#         [101,  90,  94],
#         [102,  91,  95],
#         ...,
#         [147, 136, 140],
#         [146, 135, 139],
#         [146, 135, 139]]], shape=(2160, 3840, 3), dtype=uint8)
# orig_shape: (2160, 3840)
# path: 'https_//youtu.be/S5nsDT5oU90'
# probs: None
# save_dir: 'C:\\PythonProject\\poten_up09\\runs\\detect\\predict'
# speed: {'preprocess': 1.987800000279094, 'inference': 76.35259999915434, 'postprocess': 0.8976000008260598}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[72], line 2
#       1 results = model(youtube_url, stream=True, show=True)
# ----> 2 for res in results:
#       3     print(res)
#
# File c:\PythonProject\poten_up09\.venv\Lib\site-packages\torch\utils\_contextlib.py:59, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      56         else:
#      57             # Pass the last request to the generator and get its response
#      58             with ctx_factory():
# ---> 59                 response = gen.send(request)
#      61 # We let the exceptions raised above by the generator's `.throw` or
#      62 # `.send` methods bubble up to our caller, except for StopIteration
#      63 except StopIteration as e:
#      64     # The generator informed us that it is done: take whatever its
#      65     # returned value (if any) was and indicate that we're done too
#      66     # by returning it (see docs for python's return-statement).
#
# File c:\PythonProject\poten_up09\.venv\Lib\site-packages\ultralytics\engine\predictor.py:332, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     330 # Inference
#     331 with profilers[1]:
# --> 332     preds = self.inference(im, *args, **kwargs)
#     333     if self.args.embed:
#     334         yield from [preds] if isinstance(preds, torch.Tensor) else preds  # yield embedding tensors
#
# File c:\PythonProject\poten_up09\.venv\Lib\site-packages\ultralytics\engine\predictor.py:184, in BasePredictor.inference(self, im, *args, **kwargs)
#     178 """Run inference on a given image using the specified model and arguments."""
#     179 visualize = (
#     180     increment_path(self.save_dir / Path(self.batch[0][0]).stem, mkdir=True)
#     181     if self.args.visualize and (not self.source_type.tensor)
#     182     else False
#     183 )
# --> 184 return self.model(im, augment=self.args.augment, visualize=visualize, embed=self.args.embed, *args, **kwargs)
#
# File c:\PythonProject\poten_up09\.venv\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File c:\PythonProject\poten_up09\.venv\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File c:\PythonProject\poten_up09\.venv\Lib\site-packages\ultralytics\nn\autobackend.py:637, in AutoBackend.forward(self, im, augment, visualize, embed, **kwargs)
#     635 # PyTorch
#     636 if self.pt or self.nn_module:
# --> 637     y = self.model(im, augment=augment, visualize=visualize, embed=embed, **kwargs)
#     639 # TorchScript
#     640 elif self.jit:
#
# File c:\PythonProject\poten_up09\.venv\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File c:\PythonProject\poten_up09\.venv\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File c:\PythonProject\poten_up09\.venv\Lib\site-packages\ultralytics\nn\tasks.py:139, in BaseModel.forward(self, x, *args, **kwargs)
#     137 if isinstance(x, dict):  # for cases of training and validating while training.
#     138     return self.loss(x, *args, **kwargs)
# --> 139 return self.predict(x, *args, **kwargs)
#
# File c:\PythonProject\poten_up09\.venv\Lib\site-packages\ultralytics\nn\tasks.py:157, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#     155 if augment:
#     156     return self._predict_augment(x)
# --> 157 return self._predict_once(x, profile, visualize, embed)
#
# File c:\PythonProject\poten_up09\.venv\Lib\site-packages\ultralytics\nn\tasks.py:180, in BaseModel._predict_once(self, x, profile, visualize, embed)
#     178 if profile:
#     179     self._profile_one_layer(m, x, dt)
# --> 180 x = m(x)  # run
#     181 y.append(x if m.i in self.save else None)  # save output
#     182 if visualize:
#
# File c:\PythonProject\poten_up09\.venv\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File c:\PythonProject\poten_up09\.venv\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File c:\PythonProject\poten_up09\.venv\Lib\site-packages\ultralytics\nn\modules\block.py:318, in C2f.forward(self, x)
#     316 """Forward pass through C2f layer."""
#     317 y = list(self.cv1(x).chunk(2, 1))
# --> 318 y.extend(m(y[-1]) for m in self.m)
#     319 return self.cv2(torch.cat(y, 1))
#
# File c:\PythonProject\poten_up09\.venv\Lib\site-packages\ultralytics\nn\modules\block.py:318, in <genexpr>(.0)
#     316 """Forward pass through C2f layer."""
#     317 y = list(self.cv1(x).chunk(2, 1))
# --> 318 y.extend(m(y[-1]) for m in self.m)
#     319 return self.cv2(torch.cat(y, 1))
#
# File c:\PythonProject\poten_up09\.venv\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File c:\PythonProject\poten_up09\.venv\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File c:\PythonProject\poten_up09\.venv\Lib\site-packages\ultralytics\nn\modules\block.py:495, in Bottleneck.forward(self, x)
#     493 def forward(self, x: torch.Tensor) -> torch.Tensor:
#     494     """Apply bottleneck with optional shortcut connection."""
# --> 495     return x + self.cv2(self.cv1(x)) if self.add else self.cv2(self.cv1(x))
#
# File c:\PythonProject\poten_up09\.venv\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File c:\PythonProject\poten_up09\.venv\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File c:\PythonProject\poten_up09\.venv\Lib\site-packages\ultralytics\nn\modules\conv.py:93, in Conv.forward_fuse(self, x)
#      83 def forward_fuse(self, x):
#      84     """
#      85     Apply convolution and activation without batch normalization.
#      86
#    (...)     91         (torch.Tensor): Output tensor.
#      92     """
# ---> 93     return self.act(self.conv(x))
#
# File c:\PythonProject\poten_up09\.venv\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File c:\PythonProject\poten_up09\.venv\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File c:\PythonProject\poten_up09\.venv\Lib\site-packages\torch\nn\modules\conv.py:548, in Conv2d.forward(self, input)
#     547 def forward(self, input: Tensor) -> Tensor:
# --> 548     return self._conv_forward(input, self.weight, self.bias)
#
# File c:\PythonProject\poten_up09\.venv\Lib\site-packages\torch\nn\modules\conv.py:543, in Conv2d._conv_forward(self, input, weight, bias)
#     531 if self.padding_mode != "zeros":
#     532     return F.conv2d(
#     533         F.pad(
#     534             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)    541         self.groups,
#     542     )
# --> 543 return F.conv2d(
#     544     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     545 )
#
# KeyboardInterrupt:

# %%
# cls 를 가져와서 반복문으로 names의 value 찾아오기
result[0].names
print(boxes.cls)
# Out:
# tensor([ 1.,  0.,  1.,  1.,  0.,  0.,  0.,  0.,  0., 25.,  0.])

# %%
names = results[0].names
print(names)
print(boxes.cls)

for name in boxes.cls:
    # key = name[:-1]
    key = int(name)
    print(f"{names[key]} 를 찾았습니다!")
# Out:
# {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# tensor([ 1.,  0.,  1.,  1.,  0.,  0.,  0.,  0.,  0., 25.,  0.])
# bicycle 를 찾았습니다!
# person 를 찾았습니다!
# bicycle 를 찾았습니다!
# bicycle 를 찾았습니다!
# person 를 찾았습니다!
# person 를 찾았습니다!
# person 를 찾았습니다!
# person 를 찾았습니다!
# person 를 찾았습니다!
# umbrella 를 찾았습니다!
# person 를 찾았습니다!

# %%
# image 하나로 예측하기
# results --- 이미지 개수만큼 리스트로 담겨 있었다 len(results) -> 1
# result = results[0], results.names --- 딕셔너리로 탐지할 수 있는 객체 저장되어 있음
# boxes = result.boxes --- 객체 인식한 박스 정보들이 들어가 있음
# boxes.cls, boxes.conf, boxes.data
# cls: 객체 예측한 결과
# conf: 신뢰도 
# data 박스 좌표 (x1, y1, x2, y2), 신뢰도(conf), 결과(cls)

# %%
for x1, y1, x2, y2, conf, cls in boxes.data:
    print(x1, y1, x2, y2, conf, cls)
# Out:
# tensor(627.1171) tensor(394.8538) tensor(1035.6875) tensor(771.4446) tensor(0.9002) tensor(1.)

# %% [markdown]
# # 4. 내 데이터로 학습하기

# %% [markdown]
# #### 1) 데이터 불러오기

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="COGzmoJ3Zq1uCUmSWFo2")
project = rf.workspace("potenup09-ofzh2").project("myproject-rz2si")
version = project.version(2)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Exporting format yolov11 in progress : 85.0%
# Version export complete for yolov11 format
# Downloading Dataset Version Zip in MyProject-2 to yolov11:: 100%|██████████| 1148/1148 [00:01<00:00, 916.92it/s]
# Extracting Dataset Version Zip to MyProject-2 in yolov11:: 100%|██████████| 72/72 [00:00<00:00, 2394.98it/s]

# %% [markdown]
# #### 2) 모델 불러오기

# %%
model = YOLO("yolo11n.pt")

# %% [markdown]
# #### 3) 학습하기

# %%
results = model.train(data="yolo_my_project\\data.yaml", epochs=100, imgsz=640)
# Out:
# Ultralytics 8.3.191  Python-3.11.0 torch-2.8.0+cpu CPU (Intel Core(TM) Ultra 9 185H)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=yolo_my_project\data.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train4, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=C:\PythonProject\poten_up09\runs\detect\train4, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    431062  ultralytics.nn.modules.head.Detect           [2, [64, 128, 256]]
# YOLO11n summary: 181 layers, 2,590,230 parameters, 2,590,214 gradients, 6.4 GFLOPs
#
# Transferred 448/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# train: Fast image access  (ping: 0.10.0 ms, read: 4.72.7 MB/s, size: 41.5 KB)
# train: Scanning C:\PythonProject\poten_up09\yolo_my_project\train\labels... 20 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 20/20 470.7it/s 0.0s
# train: New cache created: C:\PythonProject\poten_up09\yolo_my_project\train\labels.cache
# val: Fast image access  (ping: 0.00.0 ms, read: 3.11.4 MB/s, size: 33.8 KB)
# val: Scanning C:\PythonProject\poten_up09\yolo_my_project\valid\labels... 5 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 5/5 363.7it/s 0.0s
# val: New cache created: C:\PythonProject\poten_up09\yolo_my_project\valid\labels.cache
# Plotting labels to C:\PythonProject\poten_up09\runs\detect\train4\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001667, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to C:\PythonProject\poten_up09\runs\detect\train4
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100         0G      1.127      3.018        1.6         13        640: 100% ━━━━━━━━━━━━ 2/2 0.51it/s 3.9s2.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.6it/s 0.4s
#                    all          5          5    0.00335          1      0.209      0.134
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100         0G      1.223      3.046      1.963          8        640: 100% ━━━━━━━━━━━━ 2/2 0.57it/s 3.5s2.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.9it/s 0.3s
#                    all          5          5     0.0034          1      0.212      0.111
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100         0G     0.9611      2.898      1.515         14        640: 100% ━━━━━━━━━━━━ 2/2 0.66it/s 3.0s2.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.0it/s 0.3s
#                    all          5          5    0.00347          1     0.0998     0.0446
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100         0G     0.9248      2.923      1.427         12        640: 100% ━━━━━━━━━━━━ 2/2 0.67it/s 3.0s2.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.8it/s 0.4s
#                    all          5          5    0.00347          1      0.286      0.147
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100         0G     0.9882      2.908      1.491          9        640: 100% ━━━━━━━━━━━━ 2/2 0.63it/s 3.2s2.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.9it/s 0.3s
#                    all          5          5    0.00343          1      0.333      0.167
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100         0G     0.8866      2.921      1.477          8        640: 100% ━━━━━━━━━━━━ 2/2 0.64it/s 3.1s2.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.8it/s 0.4s
#                    all          5          5    0.00339          1      0.567      0.211
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100         0G     0.9691      2.821      1.493         10        640: 100% ━━━━━━━━━━━━ 2/2 0.61it/s 3.3s2.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.5it/s 0.4s
#                    all          5          5    0.00353          1      0.454      0.149
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100         0G       0.89      2.665      1.409         13        640: 100% ━━━━━━━━━━━━ 2/2 0.59it/s 3.4s2.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.5it/s 0.4s
#                    all          5          5    0.00357          1      0.251      0.139
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100         0G      1.037      2.715      1.561         11        640: 100% ━━━━━━━━━━━━ 2/2 0.59it/s 3.4s2.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.3it/s 0.4s
#                    all          5          5    0.00369          1      0.234      0.104
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100         0G     0.8918      2.597      1.383         14        640: 100% ━━━━━━━━━━━━ 2/2 0.59it/s 3.4s2.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.6it/s 0.4s
#                    all          5          5    0.00367          1      0.232      0.112
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100         0G     0.8093      2.498      1.316         12        640: 100% ━━━━━━━━━━━━ 2/2 0.58it/s 3.4s2.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.5it/s 0.4s
#                    all          5          5    0.00376          1      0.295      0.147
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100         0G     0.8706       2.55      1.461         10        640: 100% ━━━━━━━━━━━━ 2/2 0.67it/s 3.0s2.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.6it/s 0.4s
#                    all          5          5    0.00396          1      0.502      0.167
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100         0G     0.8574      2.521      1.448         10        640: 100% ━━━━━━━━━━━━ 2/2 0.65it/s 3.1s2.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.5it/s 0.4s
#                    all          5          5    0.00396          1      0.361      0.182
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100         0G      1.062       2.44      1.633         12        640: 100% ━━━━━━━━━━━━ 2/2 0.66it/s 3.0s2.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.4it/s 0.4s
#                    all          5          